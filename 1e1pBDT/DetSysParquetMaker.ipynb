# %%
from __future__ import print_function
from ROOT import TFile
import ROOT
import matplotlib.pyplot as plt
from matplotlib import gridspec
import numpy as np
from math import sqrt,cos,acos,pi,exp,sin,atan2,log
from numpy import arange,mean,asarray,isnan,isinf
import pickle
from scipy import stats
from root_pandas import read_root

from numpy import mean,std,asarray,vstack
from scipy.stats import gaussian_kde
import csv
import sys
import pandas as pd
import os

from SelectionHelper import BDTensemble,sysselection

datafolder = '/home/nwkamp/Research/MicroBooNE/Data'
sysfolder = '/home/nwkamp/Research/MicroBooNE/Data/systematics'
auxfolder = '/home/nwkamp/Research/MicroBooNE/1L1PSelection/aux'
dumpfolder = 'PlotDumps'

cutMode = 2

RSE  = ['run','subrun','event']
RSEV = ['run','subrun','event','vtxid']
RSECV = ['run','subrun','event',"isCV"]

dvkeys = ['Standard','Low','High']
sRSE = ['sample'] + RSE
sRSECV = ['sample'] + RSECV

good_run1_df = pd.read_csv('%s/pass_r1.txt'%auxfolder)
good_run2_df = pd.read_csv('%s/pass_r2.txt'%auxfolder)
good_run3_df = pd.read_csv('%s/pass_r3.txt'%auxfolder)

good_run1_df['good'] = 1
good_run2_df['good'] = 1
good_run3_df['good'] = 1
# Out:
# Welcome to JupyROOT 6.16/00

# %%
tag='3March2021_vA_fullLowE_withPi0Sample_newShowerCalib'
BDTnumlist=range(20)
nBDTs = len(BDTnumlist)
oldBDT = False


ensemble = BDTensemble(tag,BDTnumlist,oldBDT=oldBDT)
# Out:
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_0_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_0_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_1_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_1_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_2_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_2_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_3_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_3_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_4_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_4_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_5_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_5_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_6_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_6_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_7_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_7_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_8_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_8_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_9_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_9_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_10_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_10_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_11_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_11_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_12_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_12_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_13_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_13_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_14_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_14_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_15_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_15_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_16_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_16_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_17_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_17_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_18_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_18_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_19_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_19_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_0_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_0_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_0_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_0_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_0_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_1_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_1_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_1_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_1_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_1_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_2_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_2_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_2_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_2_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_2_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_3_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_3_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_3_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_3_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_3_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_4_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_4_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_4_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_4_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_4_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_5_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_5_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_5_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_5_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_5_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_6_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_6_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_6_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_6_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_6_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_7_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_7_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_7_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_7_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_7_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_8_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_8_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_8_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_8_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_8_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_9_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_9_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_9_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_9_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_9_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_10_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_10_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_10_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_10_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_10_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_11_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_11_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_11_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_11_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_11_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_12_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_12_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_12_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_12_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_12_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_13_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_13_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_13_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_13_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_13_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_14_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_14_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_14_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_14_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_14_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_15_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_15_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_15_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_15_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_15_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_16_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_16_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_16_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_16_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_16_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_17_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_17_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_17_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_17_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_17_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_18_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_18_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_18_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_18_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_18_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_19_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_19_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_19_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_19_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_19_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_0_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_0_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_1_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_1_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_2_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_2_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_3_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_3_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_4_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_4_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_5_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_5_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_6_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_6_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_7_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_7_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_8_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_8_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_9_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_9_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_10_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_10_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_11_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_11_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_12_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_12_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_13_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_13_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_14_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_14_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_15_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_15_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_16_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_16_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_17_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_17_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_18_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_18_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_19_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:281: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_19_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)

# %%
df_mc_detvarweight_r1_standard = read_root('%s/weights_forCV_v48_Sep24_intrinsic_nue_DetVar_run1.root'%auxfolder).drop_duplicates(RSE)
df_mc_detvarweight_r1_standard.insert(0,'sample',[dvkeys[0] for i in range(len(df_mc_detvarweight_r1_standard))])
df_mc_detvarweight_r1_low = read_root('%s/weights_forCV_v48_Sep24_eLEE_low_DetVar_run1.root'%auxfolder).drop_duplicates(RSE)
df_mc_detvarweight_r1_low.insert(0,'sample',[dvkeys[1] for i in range(len(df_mc_detvarweight_r1_low))])
df_mc_detvarweight_r1_high = read_root('%s/weights_forCV_v48_Sep24_eLEE_high_DetVar_run1.root'%auxfolder).drop_duplicates(RSE)
df_mc_detvarweight_r1_high.insert(0,'sample',[dvkeys[2] for i in range(len(df_mc_detvarweight_r1_high))])
df_mc_detvarweight_r1 = pd.concat((df_mc_detvarweight_r1_standard,df_mc_detvarweight_r1_low,df_mc_detvarweight_r1_high)).drop_duplicates(sRSE)


df_mc_detvarweight_r3_standard = read_root('%s/weights_forCV_v48_Sep24_intrinsic_nue_DetVar_run3.root'%auxfolder).drop_duplicates(RSE)
df_mc_detvarweight_r3_standard.insert(0,'sample',[dvkeys[0] for i in range(len(df_mc_detvarweight_r3_standard))])
df_mc_detvarweight_r3_low = read_root('%s/weights_forCV_v48_Sep24_eLEE_low_DetVar_run3.root'%auxfolder).drop_duplicates(RSE)
df_mc_detvarweight_r3_low.insert(0,'sample',[dvkeys[1] for i in range(len(df_mc_detvarweight_r3_low))])
df_mc_detvarweight_r3_high = read_root('%s/weights_forCV_v48_Sep24_eLEE_high_DetVar_run3.root'%auxfolder).drop_duplicates(RSE)
df_mc_detvarweight_r3_high.insert(0,'sample',[dvkeys[2] for i in range(len(df_mc_detvarweight_r3_high))])
df_mc_detvarweight_r3 = pd.concat((df_mc_detvarweight_r3_standard,df_mc_detvarweight_r3_low,df_mc_detvarweight_r3_high)).drop_duplicates(sRSE)

def performSysSelection(dv,run,sigcutlist,modelist):
    
    flist = {}
    dflist = {}
    for sigcut in sigcutlist:
        for mode in modelist:
            k = tuple((sigcut,mode))
            dflist[k] = {}
    rstr = str(run)
    try:
        if cutMode != 2:
            flist['Low'] = [TFile.Open(sysfolder+'/mcc9_v40_eLEE_low_run%s_%s_nu1e1p_signal_v1_1_3_fvv.root'%(rstr,dv)),
                            TFile.Open(sysfolder+'/mcc9_v40_eLEE_low_run%s_%s_nu1e1p_lowBDT_v1_1_3_fvv.root'%(rstr,dv))]
            filestr+='Low'
    except:
        pass
    try:
        flist['High'] = [TFile.Open(sysfolder+'/mcc9_v40_eLEE_high_run%s_%s_nu1e1p_signal_v1_1_3_fvv.root'%(rstr,dv)),
                         TFile.Open(sysfolder+'/mcc9_v40_eLEE_high_run%s_%s_nu1e1p_lowBDT_v1_1_3_fvv.root'%(rstr,dv))]
        filestr+='High'
    except:
        pass
    try:
        if run==3: rstr = '3b'
        flist['Standard'] = TFile.Open(sysfolder+'/mcc9_v40a_dl_run%s_bnb_intrinsic_nue_overlay_%s.root'%(rstr,dv))
        filestr+='Standard'
    except:
        pass
    
    print(flist.keys())
    
    for k,f in flist.items():
        if k in ['Low','High']:
            tSig = f[0].Get('dlana/FinalVertexVariables')
            tLow = f[1].Get('dlana/FinalVertexVariables')
            dfSig = sysselection(tSig,cutMode,run,k,ensemble)
            dfLow = sysselection(tLow,cutMode,run,k,ensemble)
            df = pd.concat((dfSig,dfLow))
        else:
            t = f.Get('dlana/FinalVertexVariables')
            if not t: t = f.Get('FinalVertexVariables')
            df = sysselection(t,cutMode,run,k,ensemble)
        print('%s... %i entries'%(k,len(df)))
        for sigcut in sigcutlist:
            for mode in modelist:
                dfc = df.copy()
                ensemble.MakeBDTcut(dfc,sigcut,mode)
                key = tuple((sigcut,mode))
                dflist[key][k] = dfc
    
    dfret = {}
    for sigcut in sigcutlist:
        for mode in modelist:
            key = tuple((sigcut,mode))
            dfret[key] = pd.concat([dflist[key][k] for k in flist.keys()])
        
    return dfret
    
    
    

def getFullDetvarDF_1e1p(dv,run,dfd_cv,POTCV,POTDV,sigcutlist,modelist):
    
    if run=='1':
        df_goodrun = good_run1_df
        df_wgts = df_mc_detvarweight_r1
    elif run=='3':
        df_goodrun = good_run3_df
        df_wgts = df_mc_detvarweight_r3
    else:
        print('Select either run 1 or run 3! Exiting...')
        return -1
    
    dfd_dv = performSysSelection(dv,int(run),sigcutlist,modelist)
    
    dfd_full = {}
    for k in dfd_dv.keys():
        df_cv = dfd_cv[k]
        df_dv = dfd_dv[k]
        df_cv['isCV'] = True
        df_dv['isCV'] = False
        #df_cv['POT']  = POTCV['standard']
        #df_dv['POT'] = POTDV['standard']

        df_cv['POT']  = df_cv.apply(lambda row: POTCV['standard'] + int(row.Etrue<400)*POTCV['low'] + int(row.Etrue>400 and row.Etrue<800)*POTCV['high'], axis=1)
        df_dv['POT'] = df_dv.apply(lambda row: POTDV['standard'] + int(row.Etrue<400)*POTDV['low'] + int(row.Etrue>400 and row.Etrue<800)*POTDV['high'], axis=1)
        
        #for v in df_dv[['POT','Etrue']].values: print(v)


        df_full = pd.concat((df_cv,df_dv))
        print(k,'df_full = %d  cv = %d , dv = %d'%(sum(df_full['bdtweight']>0),sum(df_cv['bdtweight']>0),sum(df_dv['bdtweight']>0)))
        df_full = df_full.join(df_wgts.set_index(sRSE)[['nu_interaction_mode','nu_interaction_type','xsec_corr_weight','spline_weight','nu_interaction_ccnc','nu_pdg','nu_energy_true','lee_weight']],on=sRSE)
        dfd_full[k] = df_full        
    return dfd_full

# %%
run1POT = {
    "CV": {'standard':2.40236914697e+22,'low':4.317567545E+23,'high':7.062363279E+22},
    "LYRayleigh": {'standard':2.35130607446e+22,'low':4.838409135E+23,'high':7.870279156E+22},
    "LYDown": {'standard':2.87664943915e+22,'low':4.418290404E+23,'high':7.363032075E+22},
    "LYAtt" : {'standard':2.92293960383e+22,'low':4.477090683E+23,'high':7.723968494E+22}
}
run3POT = {
    "CV": {'standard':2.89633486917e+22,'low':4.420872429E+23,'high':7.40598415E+22},
    "LYRayleigh": {'standard':3.12607092491e+22,'low':5.124870339E+23,'high':8.3075838217E+22},
    "LYDown": {'standard':3.02224657246e+22,'low':4.664119568E+23,'high':7.82781203E+22},
    "LYAtt" : {'standard':5.59852627949E+22,'low':4.968635449E+23,'high':8.51917546E+22},
    "recomb2" : {'standard':3.60888588249E+22,'low':4.109640309E+23,'high':5.71869841E+22},
    "SCE" : {'standard':2.87085754999e+22,'low':4.294431989E+23,'high':7.62076123E+22},
    "WireModX" : {'standard':3.20900856709e+22,'low':5.080818329E+23,'high':8.62560656E+22},
    "WireModYZ" : {'standard':2.54766720272e+22,'low':4.437820079E+23,'high':7.39558079E+22},
    "WireModThetaXZ" : {'standard':2.44011517946e+22,'low':4.544662239E+23,'high':7.50850899E+22},
    "WireModThetaYZ" : {'standard':1.95821121697e+22,'low':4.537001309E+23,'high':7.96152227E+22}
}

pklsavedir = sysfolder+'/pickles/'+tag
try: os.mkdir(pklsavedir)
except OSError as error: print(error)
    
modelist = ['avgscore']#['fracweight','medianscore','avgscore']
sigcutlist = [0.95]#[0.7,0.75,0.8,0.85,0.9,0.95]

for mode in modelist:
    pklsavedir = sysfolder+'/pickles/'+tag+'/'+mode
    try: os.mkdir(pklsavedir)
    except OSError as error: print(error)
    for sigcut in sigcutlist:
        pklsavedir = sysfolder+'/pickles/'+tag+'/'+mode+'/BDTcut'+str(sigcut)
        try: os.mkdir(pklsavedir)
        except OSError as error: print(error)


run = '1'
print('DOING RUN 1')
print('#'*5,'CV','#'*5)
dfd_cv = performSysSelection('CV',int(run),sigcutlist,modelist)
for dv in run1POT.keys():
    print('#'*5,dv,'#'*5)
    dfd_bnb_wCV_wPass_wProc = getFullDetvarDF_1e1p(dv,run,dfd_cv,run1POT['CV'],run1POT[dv],sigcutlist,modelist)
    for sigcut in sigcutlist:
        for mode in modelist: 
            pklsavedir = sysfolder+'/pickles/'+tag+'/'+mode+'/BDTcut'+str(sigcut)
            key = tuple((sigcut,mode))
            dfd_bnb_wCV_wPass_wProc[key].to_parquet(pklsavedir+'/%s_run%s_cutMode%s.parquet'%(dv,run,str(cutMode)))
            
run = '3'
print('DOING RUN 3')
print('#'*5,'CV','#'*5)
dfd_cv = performSysSelection('CV',int(run),sigcutlist,modelist)
print('#'*5,'DONE','#'*5)
for dv in run3POT.keys():
    print('#'*5,dv,'#'*5)
    dfd_bnb_wCV_wPass_wProc = getFullDetvarDF_1e1p(dv,run,dfd_cv,run3POT['CV'],run3POT[dv],sigcutlist,modelist)
    for sigcut in sigcutlist:
        for mode in modelist: 
            pklsavedir = sysfolder+'/pickles/'+tag+'/'+mode+'/BDTcut'+str(sigcut)
            key = tuple((sigcut,mode))
            dfd_bnb_wCV_wPass_wProc[key].to_parquet(pklsavedir+'/%s_run%s_cutMode%s.parquet'%(dv,run,str(cutMode)))
# Out:
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/avgscore'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/avgscore/BDTcut0.95'
# DOING RUN 1
# ##### CV #####
# ['High', 'Standard']
# High... 338 entries
# Standard... 1025 entries
# ##### LYAtt #####
# ['High', 'Standard']
# High... 360 entries
# Standard... 1231 entries
# (0.95, 'avgscore') df_full = 1439  cv = 675 , dv = 764
# ##### LYRayleigh #####
# ['High', 'Standard']
# High... 375 entries
# Standard... 996 entries
# (0.95, 'avgscore') df_full = 1361  cv = 675 , dv = 686
# ##### CV #####
# ['High', 'Standard']
# High... 338 entries
# Standard... 1025 entries
# (0.95, 'avgscore') df_full = 1350  cv = 675 , dv = 675
# ##### LYDown #####
# ['High', 'Standard']
# High... 351 entries
# Standard... 1239 entries
# (0.95, 'avgscore') df_full = 1447  cv = 675 , dv = 772
# DOING RUN 3
# ##### CV #####
# ['High', 'Standard']
# High... 330 entries
# Standard... 1229 entries
# ##### DONE #####
# ##### WireModThetaYZ #####
# ['High', 'Standard']
# High... 364 entries
# Standard... 877 entries
# (0.95, 'avgscore') df_full = 1135  cv = 635 , dv = 500
# ##### WireModThetaXZ #####
# ['High', 'Standard']
# High... 333 entries
# Standard... 1106 entries
# (0.95, 'avgscore') df_full = 1212  cv = 635 , dv = 577
# ##### WireModX #####
# ['High', 'Standard']
# High... 395 entries
# Standard... 1333 entries
# (0.95, 'avgscore') df_full = 1304  cv = 635 , dv = 669
# ##### LYAtt #####
# ['High', 'Standard']
# High... 385 entries
# Standard... 2500 entries
# (0.95, 'avgscore') df_full = 1684  cv = 635 , dv = 1049
# ##### LYRayleigh #####
# ['High', 'Standard']
# High... 358 entries
# Standard... 1324 entries
# (0.95, 'avgscore') df_full = 1323  cv = 635 , dv = 688
# ##### WireModYZ #####
# ['High', 'Standard']
# High... 331 entries
# Standard... 1143 entries
# (0.95, 'avgscore') df_full = 1229  cv = 635 , dv = 594
# ##### LYDown #####
# ['High', 'Standard']
# High... 344 entries
# Standard... 1274 entries
# (0.95, 'avgscore') df_full = 1283  cv = 635 , dv = 648
# ##### SCE #####
# ['High', 'Standard']
# High... 337 entries
# Standard... 1251 entries
# (0.95, 'avgscore') df_full = 1267  cv = 635 , dv = 632
# ##### CV #####
# ['High', 'Standard']
# High... 330 entries
# Standard... 1229 entries
# (0.95, 'avgscore') df_full = 1270  cv = 635 , dv = 635
# ##### recomb2 #####
# ['High', 'Standard']
# High... 271 entries
# Standard... 1677 entries
# (0.95, 'avgscore') df_full = 1351  cv = 635 , dv = 716
