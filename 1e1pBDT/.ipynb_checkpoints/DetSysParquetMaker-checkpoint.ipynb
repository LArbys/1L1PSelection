# %%
from __future__ import print_function
from ROOT import TFile
import ROOT
import matplotlib.pyplot as plt
from matplotlib import gridspec
import numpy as np
from math import sqrt,cos,acos,pi,exp,sin,atan2,log
from numpy import arange,mean,asarray,isnan,isinf
import pickle
from scipy import stats
from root_pandas import read_root

from numpy import mean,std,asarray,vstack
from scipy.stats import gaussian_kde
import csv
import sys
import pandas as pd
import os

from SelectionHelper import BDTensemble,sysselection

datafolder = '/home/nwkamp/Research/MicroBooNE/Data'
sysfolder = '/home/nwkamp/Research/MicroBooNE/Data/systematics'
auxfolder = '/home/nwkamp/Research/MicroBooNE/1L1PSelection/aux'
dumpfolder = 'PlotDumps'

cutMode = 0

RSE  = ['run','subrun','event']
RSEV = ['run','subrun','event','vtxid']
RSECV = ['run','subrun','event',"isCV"]

dvkeys = ['Standard','Low','High']
sRSE = ['sample'] + RSE
sRSECV = ['sample'] + RSECV

good_run1_df = pd.read_csv('%s/pass_r1.txt'%auxfolder)
good_run2_df = pd.read_csv('%s/pass_r2.txt'%auxfolder)
good_run3_df = pd.read_csv('%s/pass_r3.txt'%auxfolder)

good_run1_df['good'] = 1
good_run2_df['good'] = 1
good_run3_df['good'] = 1
# Out:
# Welcome to JupyROOT 6.16/00

# %%
tag='3March2021_vA_fullLowE_withPi0Sample_newShowerCalib'
BDTnumlist=range(20)
nBDTs = len(BDTnumlist)
oldBDT = False


ensemble = BDTensemble(tag,BDTnumlist,oldBDT=oldBDT)
# Out:
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_0_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_0_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_1_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_1_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_2_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_2_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_3_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_3_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_4_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_4_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_5_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_5_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_6_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_6_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_7_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_7_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_8_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_8_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_9_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_9_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_10_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_10_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_11_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_11_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_12_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_12_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_13_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_13_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_14_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_14_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_15_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_15_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_16_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_16_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_17_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_17_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_18_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_18_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_19_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R1_19_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_0_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_0_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_0_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_0_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_0_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_1_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_1_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_1_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_1_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_1_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_2_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_2_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_2_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_2_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_2_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_3_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_3_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_3_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_3_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_3_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_4_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_4_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_4_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_4_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_4_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_5_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_5_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_5_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_5_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_5_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_6_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_6_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_6_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_6_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_6_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_7_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_7_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_7_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_7_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_7_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_8_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_8_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_8_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_8_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_8_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_9_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_9_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_9_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_9_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_9_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_10_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_10_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_10_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_10_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_10_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_11_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_11_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_11_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_11_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_11_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_12_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_12_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_12_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_12_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_12_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_13_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_13_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_13_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_13_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_13_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_14_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_14_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_14_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_14_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_14_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_15_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_15_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_15_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_15_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_15_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_16_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_16_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_16_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_16_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_16_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_17_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_17_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_17_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_17_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_17_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_18_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_18_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_18_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_18_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_18_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_19_ext.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_19_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_19_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_19_ccpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R2_19_ncpi0.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_0_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_0_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_1_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_1_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_2_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_2_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_3_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_3_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_4_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_4_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_5_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_5_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_6_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_6_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_7_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_7_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_8_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_8_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_9_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_9_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_10_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_10_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_11_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_11_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_12_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_12_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_13_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_13_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_14_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_14_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_15_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_15_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_16_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_16_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_17_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_17_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_18_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_18_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_19_intrinsics_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)
# SelectionHelper.py:282: UserWarning: loadtxt: Empty input file: "/home/nwkamp/Research/MicroBooNE/1e1pSelectionPrime/BDT/BDTWeights/new/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/ValSample_R3_19_overlay_lowE.txt"
#   self.valrse[r][b][filetag] = np.loadtxt(bdtsavedir+'ValSample_R%i_%i_%s.txt'%(r,b,filetag),dtype=int)

# %%
df_mc_detvarweight_r1_standard = read_root('%s/weights_forCV_v48_Sep24_intrinsic_nue_DetVar_run1.root'%auxfolder).drop_duplicates(RSE)
df_mc_detvarweight_r1_standard.insert(0,'sample',[dvkeys[0] for i in range(len(df_mc_detvarweight_r1_standard))])
df_mc_detvarweight_r1_low = read_root('%s/weights_forCV_v48_Sep24_eLEE_low_DetVar_run1.root'%auxfolder).drop_duplicates(RSE)
df_mc_detvarweight_r1_low.insert(0,'sample',[dvkeys[1] for i in range(len(df_mc_detvarweight_r1_low))])
df_mc_detvarweight_r1_high = read_root('%s/weights_forCV_v48_Sep24_eLEE_high_DetVar_run1.root'%auxfolder).drop_duplicates(RSE)
df_mc_detvarweight_r1_high.insert(0,'sample',[dvkeys[2] for i in range(len(df_mc_detvarweight_r1_high))])
df_mc_detvarweight_r1 = pd.concat((df_mc_detvarweight_r1_standard,df_mc_detvarweight_r1_low,df_mc_detvarweight_r1_high)).drop_duplicates(sRSE)


df_mc_detvarweight_r3_standard = read_root('%s/weights_forCV_v48_Sep24_intrinsic_nue_DetVar_run3.root'%auxfolder).drop_duplicates(RSE)
df_mc_detvarweight_r3_standard.insert(0,'sample',[dvkeys[0] for i in range(len(df_mc_detvarweight_r3_standard))])
df_mc_detvarweight_r3_low = read_root('%s/weights_forCV_v48_Sep24_eLEE_low_DetVar_run3.root'%auxfolder).drop_duplicates(RSE)
df_mc_detvarweight_r3_low.insert(0,'sample',[dvkeys[1] for i in range(len(df_mc_detvarweight_r3_low))])
df_mc_detvarweight_r3_high = read_root('%s/weights_forCV_v48_Sep24_eLEE_high_DetVar_run3.root'%auxfolder).drop_duplicates(RSE)
df_mc_detvarweight_r3_high.insert(0,'sample',[dvkeys[2] for i in range(len(df_mc_detvarweight_r3_high))])
df_mc_detvarweight_r3 = pd.concat((df_mc_detvarweight_r3_standard,df_mc_detvarweight_r3_low,df_mc_detvarweight_r3_high)).drop_duplicates(sRSE)

def performSysSelection(dv,run,sigcutlist,modelist):
    
    flist = {}
    dflist = {}
    for sigcut in sigcutlist:
        for mode in modelist:
            k = tuple((sigcut,mode))
            dflist[k] = {}
    rstr = str(run)
    try:
        flist['Low'] = [TFile.Open(sysfolder+'/mcc9_v40_eLEE_low_run%s_%s_nu1e1p_signal_v1_1_3_fvv.root'%(rstr,dv)),
                        TFile.Open(sysfolder+'/mcc9_v40_eLEE_low_run%s_%s_nu1e1p_lowBDT_v1_1_3_fvv.root'%(rstr,dv))]
        filestr+='Low'
    except:
        pass
    try:
        flist['High'] = [TFile.Open(sysfolder+'/mcc9_v40_eLEE_high_run%s_%s_nu1e1p_signal_v1_1_3_fvv.root'%(rstr,dv)),
                         TFile.Open(sysfolder+'/mcc9_v40_eLEE_high_run%s_%s_nu1e1p_lowBDT_v1_1_3_fvv.root'%(rstr,dv))]
        filestr+='High'
    except:
        pass
    try:
        if run==3: rstr = '3b'
        flist['Standard'] = TFile.Open(sysfolder+'/mcc9_v40a_dl_run%s_bnb_intrinsic_nue_overlay_%s.root'%(rstr,dv))
        filestr+='Standard'
    except:
        pass
    
    print(flist.keys())
    
    for k,f in flist.items():
        if k in ['Low','High']:
            tSig = f[0].Get('dlana/FinalVertexVariables')
            tLow = f[1].Get('dlana/FinalVertexVariables')
            dfSig = sysselection(tSig,cutMode,run,k,ensemble)
            dfLow = sysselection(tLow,cutMode,run,k,ensemble)
            df = pd.concat((dfSig,dfLow))
        else:
            t = f.Get('dlana/FinalVertexVariables')
            if not t: t = f.Get('FinalVertexVariables')
            df = sysselection(t,cutMode,run,k,ensemble)
        print('%s... %i entries'%(k,len(df)))
        for sigcut in sigcutlist:
            for mode in modelist:
                dfc = df.copy()
                ensemble.MakeBDTcut(dfc,sigcut,mode)
                key = tuple((sigcut,mode))
                dflist[key][k] = dfc
    
    dfret = {}
    for sigcut in sigcutlist:
        for mode in modelist:
            key = tuple((sigcut,mode))
            dfret[key] = pd.concat([dflist[key][k] for k in flist.keys()])
        
    return dfret
    
    
    

def getFullDetvarDF_1e1p(dv,run,dfd_cv,POTCV,POTDV,sigcutlist,modelist):
    
    if run=='1':
        df_goodrun = good_run1_df
        df_wgts = df_mc_detvarweight_r1
    elif run=='3':
        df_goodrun = good_run3_df
        df_wgts = df_mc_detvarweight_r3
    else:
        print('Select either run 1 or run 3! Exiting...')
        return -1
    
    dfd_dv = performSysSelection(dv,int(run),sigcutlist,modelist)
    
    dfd_full = {}
    for k in dfd_dv.keys():
        df_cv = dfd_cv[k]
        df_dv = dfd_dv[k]
        df_cv['isCV'] = True
        df_dv['isCV'] = False
        #df_cv['POT']  = POTCV['standard']
        #df_dv['POT'] = POTDV['standard']

        df_cv['POT']  = df_cv.apply(lambda row: POTCV['standard'] + int(row.Etrue<400)*POTCV['low'] + int(row.Etrue>400 and row.Etrue<800)*POTCV['high'], axis=1)
        df_dv['POT'] = df_dv.apply(lambda row: POTDV['standard'] + int(row.Etrue<400)*POTDV['low'] + int(row.Etrue>400 and row.Etrue<800)*POTDV['high'], axis=1)
        
        #for v in df_dv[['POT','Etrue']].values: print(v)


        df_full = pd.concat((df_cv,df_dv))
        print(k,'df_full = %d  cv = %d , dv = %d'%(sum(df_full['bdtweight']>0),sum(df_cv['bdtweight']>0),sum(df_dv['bdtweight']>0)))
        df_full = df_full.join(df_wgts.set_index(sRSE)[['nu_interaction_mode','nu_interaction_type','xsec_corr_weight','spline_weight','nu_interaction_ccnc','nu_pdg','nu_energy_true','lee_weight']],on=sRSE)
        dfd_full[k] = df_full        
    return dfd_full

# %%
run1POT = {
    "CV": {'standard':2.40236914697e+22,'low':4.317567545E+23,'high':7.062363279E+22},
    "LYRayleigh": {'standard':2.35130607446e+22,'low':4.838409135E+23,'high':7.870279156E+22},
    "LYDown": {'standard':2.87664943915e+22,'low':4.418290404E+23,'high':7.363032075E+22},
    "LYAtt" : {'standard':2.92293960383e+22,'low':4.477090683E+23,'high':7.723968494E+22}
}
run3POT = {
    "CV": {'standard':2.89633486917e+22,'low':4.420872429E+23,'high':7.40598415E+22},
    "LYRayleigh": {'standard':3.12607092491e+22,'low':5.124870339E+23,'high':8.3075838217E+22},
    "LYDown": {'standard':3.02224657246e+22,'low':4.664119568E+23,'high':7.82781203E+22},
    "LYAtt" : {'standard':5.59852627949E+22,'low':4.968635449E+23,'high':8.51917546E+22},
    "recomb2" : {'standard':3.60888588249E+22,'low':4.109640309E+23,'high':5.71869841E+22},
    "SCE" : {'standard':2.87085754999e+22,'low':4.294431989E+23,'high':7.62076123E+22},
    "WireModX" : {'standard':3.20900856709e+22,'low':5.080818329E+23,'high':8.62560656E+22},
    "WireModYZ" : {'standard':2.54766720272e+22,'low':4.437820079E+23,'high':7.39558079E+22},
    "WireModThetaXZ" : {'standard':2.44011517946e+22,'low':4.544662239E+23,'high':7.50850899E+22},
    "WireModThetaYZ" : {'standard':1.95821121697e+22,'low':4.537001309E+23,'high':7.96152227E+22}
}

pklsavedir = sysfolder+'/pickles/'+tag
try: os.mkdir(pklsavedir)
except OSError as error: print(error)
    
modelist = ['fracweight','medianscore','avgscore']
sigcutlist = [0.7,0.75,0.8,0.85,0.9,0.95]

for mode in modelist:
    pklsavedir = sysfolder+'/pickles/'+tag+'/'+mode
    try: os.mkdir(pklsavedir)
    except OSError as error: print(error)
    for sigcut in sigcutlist:
        pklsavedir = sysfolder+'/pickles/'+tag+'/'+mode+'/BDTcut'+str(sigcut)
        try: os.mkdir(pklsavedir)
        except OSError as error: print(error)


run = '1'
print('DOING RUN 1')
print('#'*5,'CV','#'*5)
dfd_cv = performSysSelection('CV',int(run),sigcutlist,modelist)
for dv in run1POT.keys():
    print('#'*5,dv,'#'*5)
    dfd_bnb_wCV_wPass_wProc = getFullDetvarDF_1e1p(dv,run,dfd_cv,run1POT['CV'],run1POT[dv],sigcutlist,modelist)
    for sigcut in sigcutlist:
        for mode in modelist: 
            pklsavedir = sysfolder+'/pickles/'+tag+'/'+mode+'/BDTcut'+str(sigcut)
            key = tuple((sigcut,mode))
            dfd_bnb_wCV_wPass_wProc[key].to_parquet(pklsavedir+'/%s_run%s_cutMode%s.parquet'%(dv,run,str(cutMode)))
            
run = '3'
print('DOING RUN 3')
print('#'*5,'CV','#'*5)
dfd_cv = performSysSelection('CV',int(run),sigcutlist,modelist)
print('#'*5,'DONE','#'*5)
for dv in run3POT.keys():
    print('#'*5,dv,'#'*5)
    dfd_bnb_wCV_wPass_wProc = getFullDetvarDF_1e1p(dv,run,dfd_cv,run3POT['CV'],run3POT[dv],sigcutlist,modelist)
    for sigcut in sigcutlist:
        for mode in modelist: 
            pklsavedir = sysfolder+'/pickles/'+tag+'/'+mode+'/BDTcut'+str(sigcut)
            key = tuple((sigcut,mode))
            dfd_bnb_wCV_wPass_wProc[key].to_parquet(pklsavedir+'/%s_run%s_cutMode%s.parquet'%(dv,run,str(cutMode)))
# Out:
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/fracweight'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/fracweight/BDTcut0.7'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/fracweight/BDTcut0.75'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/fracweight/BDTcut0.8'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/fracweight/BDTcut0.85'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/fracweight/BDTcut0.9'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/fracweight/BDTcut0.95'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/medianscore'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/medianscore/BDTcut0.7'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/medianscore/BDTcut0.75'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/medianscore/BDTcut0.8'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/medianscore/BDTcut0.85'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/medianscore/BDTcut0.9'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/medianscore/BDTcut0.95'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/avgscore'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/avgscore/BDTcut0.7'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/avgscore/BDTcut0.75'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/avgscore/BDTcut0.8'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/avgscore/BDTcut0.85'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/avgscore/BDTcut0.9'
# [Errno 17] File exists: '/home/nwkamp/Research/MicroBooNE/Data/systematics/pickles/3March2021_vA_fullLowE_withPi0Sample_newShowerCalib/avgscore/BDTcut0.95'
# DOING RUN 1
# ##### CV #####
# ['High', 'Low', 'Standard']
# High... 2204 entries
# Low... 1767 entries
# Standard... 3046 entries
# ##### LYAtt #####
# ['High', 'Low', 'Standard']
# High... 2354 entries
# Low... 1817 entries
# Standard... 3700 entries
# (0.7, 'fracweight') df_full = 9294  cv = 4407 , dv = 4887
# (0.9, 'medianscore') df_full = 7155  cv = 3399 , dv = 3756
# (0.95, 'medianscore') df_full = 6291  cv = 2979 , dv = 3312
# (0.95, 'avgscore') df_full = 6094  cv = 2889 , dv = 3205
# (0.9, 'avgscore') df_full = 6979  cv = 3312 , dv = 3667
# (0.7, 'medianscore') df_full = 8331  cv = 3942 , dv = 4389
# (0.8, 'medianscore') df_full = 7884  cv = 3748 , dv = 4136
# (0.8, 'fracweight') df_full = 8972  cv = 4249 , dv = 4723
# (0.7, 'avgscore') df_full = 8233  cv = 3894 , dv = 4339
# (0.85, 'avgscore') df_full = 7441  cv = 3529 , dv = 3912
# (0.75, 'avgscore') df_full = 8021  cv = 3799 , dv = 4222
# (0.85, 'medianscore') df_full = 7594  cv = 3604 , dv = 3990
# (0.8, 'avgscore') df_full = 7772  cv = 3693 , dv = 4079
# (0.75, 'fracweight') df_full = 9152  cv = 4341 , dv = 4811
# (0.75, 'medianscore') df_full = 8115  cv = 3841 , dv = 4274
# (0.85, 'fracweight') df_full = 8696  cv = 4118 , dv = 4578
# (0.9, 'fracweight') df_full = 8313  cv = 3931 , dv = 4382
# (0.95, 'fracweight') df_full = 7625  cv = 3605 , dv = 4020
# ##### LYRayleigh #####
# ['High', 'Low', 'Standard']
# High... 2442 entries
# Low... 1976 entries
# Standard... 2911 entries
# (0.7, 'fracweight') df_full = 8995  cv = 4407 , dv = 4588
# (0.9, 'medianscore') df_full = 6950  cv = 3399 , dv = 3551
# (0.95, 'medianscore') df_full = 6104  cv = 2979 , dv = 3125
# (0.95, 'avgscore') df_full = 5916  cv = 2889 , dv = 3027
# (0.9, 'avgscore') df_full = 6770  cv = 3312 , dv = 3458
# (0.7, 'medianscore') df_full = 8031  cv = 3942 , dv = 4089
# (0.8, 'medianscore') df_full = 7652  cv = 3748 , dv = 3904
# (0.8, 'fracweight') df_full = 8669  cv = 4249 , dv = 4420
# (0.7, 'avgscore') df_full = 7946  cv = 3894 , dv = 4052
# (0.85, 'avgscore') df_full = 7239  cv = 3529 , dv = 3710
# (0.75, 'avgscore') df_full = 7769  cv = 3799 , dv = 3970
# (0.85, 'medianscore') df_full = 7373  cv = 3604 , dv = 3769
# (0.8, 'avgscore') df_full = 7540  cv = 3693 , dv = 3847
# (0.75, 'fracweight') df_full = 8846  cv = 4341 , dv = 4505
# (0.75, 'medianscore') df_full = 7841  cv = 3841 , dv = 4000
# (0.85, 'fracweight') df_full = 8397  cv = 4118 , dv = 4279
# (0.9, 'fracweight') df_full = 8030  cv = 3931 , dv = 4099
# (0.95, 'fracweight') df_full = 7382  cv = 3605 , dv = 3777
# ##### CV #####
# ['High', 'Low', 'Standard']
# High... 2204 entries
# Low... 1767 entries
# Standard... 3046 entries
# (0.7, 'fracweight') df_full = 8814  cv = 4407 , dv = 4407
# (0.9, 'medianscore') df_full = 6798  cv = 3399 , dv = 3399
# (0.95, 'medianscore') df_full = 5958  cv = 2979 , dv = 2979
# (0.95, 'avgscore') df_full = 5778  cv = 2889 , dv = 2889
# (0.9, 'avgscore') df_full = 6624  cv = 3312 , dv = 3312
# (0.7, 'medianscore') df_full = 7884  cv = 3942 , dv = 3942
# (0.8, 'medianscore') df_full = 7496  cv = 3748 , dv = 3748
# (0.8, 'fracweight') df_full = 8498  cv = 4249 , dv = 4249
# (0.7, 'avgscore') df_full = 7788  cv = 3894 , dv = 3894
# (0.85, 'avgscore') df_full = 7058  cv = 3529 , dv = 3529
# (0.75, 'avgscore') df_full = 7598  cv = 3799 , dv = 3799
# (0.85, 'medianscore') df_full = 7208  cv = 3604 , dv = 3604
# (0.8, 'avgscore') df_full = 7386  cv = 3693 , dv = 3693
# (0.75, 'fracweight') df_full = 8682  cv = 4341 , dv = 4341
# (0.75, 'medianscore') df_full = 7682  cv = 3841 , dv = 3841
# (0.85, 'fracweight') df_full = 8236  cv = 4118 , dv = 4118
# (0.9, 'fracweight') df_full = 7862  cv = 3931 , dv = 3931
# (0.95, 'fracweight') df_full = 7210  cv = 3605 , dv = 3605
# ##### LYDown #####
# ['High', 'Low', 'Standard']
# High... 2277 entries
# Low... 1809 entries
# Standard... 3651 entries
# (0.7, 'fracweight') df_full = 9196  cv = 4407 , dv = 4789
# (0.9, 'medianscore') df_full = 7119  cv = 3399 , dv = 3720
# (0.95, 'medianscore') df_full = 6246  cv = 2979 , dv = 3267
# (0.95, 'avgscore') df_full = 6034  cv = 2889 , dv = 3145
# (0.9, 'avgscore') df_full = 6929  cv = 3312 , dv = 3617
# (0.7, 'medianscore') df_full = 8244  cv = 3942 , dv = 4302
# (0.8, 'medianscore') df_full = 7839  cv = 3748 , dv = 4091
# (0.8, 'fracweight') df_full = 8875  cv = 4249 , dv = 4626
# (0.7, 'avgscore') df_full = 8155  cv = 3894 , dv = 4261
# (0.85, 'avgscore') df_full = 7395  cv = 3529 , dv = 3866
# (0.75, 'avgscore') df_full = 7952  cv = 3799 , dv = 4153
# (0.85, 'medianscore') df_full = 7537  cv = 3604 , dv = 3933
# (0.8, 'avgscore') df_full = 7716  cv = 3693 , dv = 4023
# (0.75, 'fracweight') df_full = 9067  cv = 4341 , dv = 4726
# (0.75, 'medianscore') df_full = 8039  cv = 3841 , dv = 4198
# (0.85, 'fracweight') df_full = 8622  cv = 4118 , dv = 4504
# (0.9, 'fracweight') df_full = 8222  cv = 3931 , dv = 4291
# (0.95, 'fracweight') df_full = 7561  cv = 3605 , dv = 3956
# DOING RUN 3
# ##### CV #####
# ['High', 'Low', 'Standard']
# High... 2338 entries
# Low... 1810 entries
# Standard... 3690 entries
# ##### DONE #####
# ##### WireModThetaYZ #####
# ['High', 'Low', 'Standard']
# High... 2530 entries
# Low... 1854 entries
# Standard... 2556 entries
# (0.7, 'fracweight') df_full = 8491  cv = 4550 , dv = 3941
# (0.9, 'medianscore') df_full = 6302  cv = 3349 , dv = 2953
# (0.95, 'medianscore') df_full = 5548  cv = 2941 , dv = 2607
# (0.95, 'avgscore') df_full = 5322  cv = 2812 , dv = 2510
# (0.9, 'avgscore') df_full = 6123  cv = 3251 , dv = 2872
# (0.7, 'medianscore') df_full = 7494  cv = 4000 , dv = 3494
# (0.8, 'medianscore') df_full = 7015  cv = 3742 , dv = 3273
# (0.8, 'fracweight') df_full = 8136  cv = 4357 , dv = 3779
# (0.7, 'avgscore') df_full = 7407  cv = 3954 , dv = 3453
# (0.85, 'avgscore') df_full = 6539  cv = 3479 , dv = 3060
# (0.75, 'avgscore') df_full = 7156  cv = 3813 , dv = 3343
# (0.85, 'medianscore') df_full = 6691  cv = 3562 , dv = 3129
# (0.8, 'avgscore') df_full = 6875  cv = 3667 , dv = 3208
# (0.75, 'fracweight') df_full = 8344  cv = 4464 , dv = 3880
# (0.75, 'medianscore') df_full = 7269  cv = 3882 , dv = 3387
# (0.85, 'fracweight') df_full = 7905  cv = 4232 , dv = 3673
# (0.9, 'fracweight') df_full = 7510  cv = 4029 , dv = 3481
# (0.95, 'fracweight') df_full = 6789  cv = 3630 , dv = 3159
# ##### WireModThetaXZ #####
# ['High', 'Low', 'Standard']
# High... 2368 entries
# Low... 1873 entries
# Standard... 3163 entries
# (0.7, 'fracweight') df_full = 8924  cv = 4550 , dv = 4374
# (0.9, 'medianscore') df_full = 6599  cv = 3349 , dv = 3250
# (0.95, 'medianscore') df_full = 5782  cv = 2941 , dv = 2841
# (0.95, 'avgscore') df_full = 5558  cv = 2812 , dv = 2746
# (0.9, 'avgscore') df_full = 6401  cv = 3251 , dv = 3150
# (0.7, 'medianscore') df_full = 7822  cv = 4000 , dv = 3822
# (0.8, 'medianscore') df_full = 7350  cv = 3742 , dv = 3608
# (0.8, 'fracweight') df_full = 8538  cv = 4357 , dv = 4181
# (0.7, 'avgscore') df_full = 7738  cv = 3954 , dv = 3784
# (0.85, 'avgscore') df_full = 6840  cv = 3479 , dv = 3361
# (0.75, 'avgscore') df_full = 7483  cv = 3813 , dv = 3670
# (0.85, 'medianscore') df_full = 7000  cv = 3562 , dv = 3438
# (0.8, 'avgscore') df_full = 7195  cv = 3667 , dv = 3528
# (0.75, 'fracweight') df_full = 8766  cv = 4464 , dv = 4302
# (0.75, 'medianscore') df_full = 7617  cv = 3882 , dv = 3735
# (0.85, 'fracweight') df_full = 8286  cv = 4232 , dv = 4054
# (0.9, 'fracweight') df_full = 7876  cv = 4029 , dv = 3847
# (0.95, 'fracweight') df_full = 7118  cv = 3630 , dv = 3488
# ##### WireModX #####
# ['High', 'Low', 'Standard']
# High... 2668 entries
# Low... 2124 entries
# Standard... 3948 entries
# (0.7, 'fracweight') df_full = 9717  cv = 4550 , dv = 5167
# (0.9, 'medianscore') df_full = 7172  cv = 3349 , dv = 3823
# (0.95, 'medianscore') df_full = 6292  cv = 2941 , dv = 3351
# (0.95, 'avgscore') df_full = 6009  cv = 2812 , dv = 3197
# (0.9, 'avgscore') df_full = 6959  cv = 3251 , dv = 3708
# (0.7, 'medianscore') df_full = 8527  cv = 4000 , dv = 4527
# (0.8, 'medianscore') df_full = 7998  cv = 3742 , dv = 4256
# (0.8, 'fracweight') df_full = 9300  cv = 4357 , dv = 4943
# (0.7, 'avgscore') df_full = 8420  cv = 3954 , dv = 4466
# (0.85, 'avgscore') df_full = 7455  cv = 3479 , dv = 3976
# (0.75, 'avgscore') df_full = 8152  cv = 3813 , dv = 4339
# (0.85, 'medianscore') df_full = 7637  cv = 3562 , dv = 4075
# (0.8, 'avgscore') df_full = 7834  cv = 3667 , dv = 4167
# (0.75, 'fracweight') df_full = 9531  cv = 4464 , dv = 5067
# (0.75, 'medianscore') df_full = 8283  cv = 3882 , dv = 4401
# (0.85, 'fracweight') df_full = 9024  cv = 4232 , dv = 4792
# (0.9, 'fracweight') df_full = 8585  cv = 4029 , dv = 4556
# (0.95, 'fracweight') df_full = 7757  cv = 3630 , dv = 4127
# ##### LYAtt #####
# ['High', 'Low', 'Standard']
# High... 2680 entries
# Low... 2000 entries
# Standard... 7318 entries
# (0.7, 'fracweight') df_full = 11315  cv = 4550 , dv = 6765
# (0.9, 'medianscore') df_full = 8254  cv = 3349 , dv = 4905
# (0.95, 'medianscore') df_full = 7194  cv = 2941 , dv = 4253
# (0.95, 'avgscore') df_full = 6886  cv = 2812 , dv = 4074
# (0.9, 'avgscore') df_full = 8018  cv = 3251 , dv = 4767
# (0.7, 'medianscore') df_full = 9900  cv = 4000 , dv = 5900
# (0.8, 'medianscore') df_full = 9253  cv = 3742 , dv = 5511
# (0.8, 'fracweight') df_full = 10795  cv = 4357 , dv = 6438
# (0.7, 'avgscore') df_full = 9778  cv = 3954 , dv = 5824
# (0.85, 'avgscore') df_full = 8595  cv = 3479 , dv = 5116
# (0.75, 'avgscore') df_full = 9421  cv = 3813 , dv = 5608
# (0.85, 'medianscore') df_full = 8807  cv = 3562 , dv = 5245
# (0.8, 'avgscore') df_full = 9074  cv = 3667 , dv = 5407
# (0.75, 'fracweight') df_full = 11095  cv = 4464 , dv = 6631
# (0.75, 'medianscore') df_full = 9594  cv = 3882 , dv = 5712
# (0.85, 'fracweight') df_full = 10461  cv = 4232 , dv = 6229
# (0.9, 'fracweight') df_full = 9965  cv = 4029 , dv = 5936
# (0.95, 'fracweight') df_full = 8968  cv = 3630 , dv = 5338
# ##### LYRayleigh #####
# ['High', 'Low', 'Standard']
# High... 2619 entries
# Low... 2106 entries
# Standard... 4013 entries
# (0.7, 'fracweight') df_full = 9687  cv = 4550 , dv = 5137
# (0.9, 'medianscore') df_full = 7094  cv = 3349 , dv = 3745
# (0.95, 'medianscore') df_full = 6214  cv = 2941 , dv = 3273
# (0.95, 'avgscore') df_full = 5975  cv = 2812 , dv = 3163
# (0.9, 'avgscore') df_full = 6894  cv = 3251 , dv = 3643
# (0.7, 'medianscore') df_full = 8491  cv = 4000 , dv = 4491
# (0.8, 'medianscore') df_full = 7949  cv = 3742 , dv = 4207
# (0.8, 'fracweight') df_full = 9262  cv = 4357 , dv = 4905
# (0.7, 'avgscore') df_full = 8393  cv = 3954 , dv = 4439
# (0.85, 'avgscore') df_full = 7383  cv = 3479 , dv = 3904
# (0.75, 'avgscore') df_full = 8101  cv = 3813 , dv = 4288
# (0.85, 'medianscore') df_full = 7562  cv = 3562 , dv = 4000
# (0.8, 'avgscore') df_full = 7794  cv = 3667 , dv = 4127
# (0.75, 'fracweight') df_full = 9502  cv = 4464 , dv = 5038
# (0.75, 'medianscore') df_full = 8251  cv = 3882 , dv = 4369
# (0.85, 'fracweight') df_full = 8966  cv = 4232 , dv = 4734
# (0.9, 'fracweight') df_full = 8537  cv = 4029 , dv = 4508
# (0.95, 'fracweight') df_full = 7709  cv = 3630 , dv = 4079
# ##### WireModYZ #####
# ['High', 'Low', 'Standard']
# High... 2301 entries
# Low... 1843 entries
# Standard... 3296 entries
# (0.7, 'fracweight') df_full = 8946  cv = 4550 , dv = 4396
# (0.9, 'medianscore') df_full = 6610  cv = 3349 , dv = 3261
# (0.95, 'medianscore') df_full = 5778  cv = 2941 , dv = 2837
# (0.95, 'avgscore') df_full = 5544  cv = 2812 , dv = 2732
# (0.9, 'avgscore') df_full = 6412  cv = 3251 , dv = 3161
# (0.7, 'medianscore') df_full = 7842  cv = 4000 , dv = 3842
# (0.8, 'medianscore') df_full = 7352  cv = 3742 , dv = 3610
# (0.8, 'fracweight') df_full = 8574  cv = 4357 , dv = 4217
# (0.7, 'avgscore') df_full = 7759  cv = 3954 , dv = 3805
# (0.85, 'avgscore') df_full = 6863  cv = 3479 , dv = 3384
# (0.75, 'avgscore') df_full = 7493  cv = 3813 , dv = 3680
# (0.85, 'medianscore') df_full = 7026  cv = 3562 , dv = 3464
# (0.8, 'avgscore') df_full = 7211  cv = 3667 , dv = 3544
# (0.75, 'fracweight') df_full = 8784  cv = 4464 , dv = 4320
# (0.75, 'medianscore') df_full = 7627  cv = 3882 , dv = 3745
# (0.85, 'fracweight') df_full = 8315  cv = 4232 , dv = 4083
# (0.9, 'fracweight') df_full = 7902  cv = 4029 , dv = 3873
# (0.95, 'fracweight') df_full = 7146  cv = 3630 , dv = 3516
# ##### LYDown #####
# ['High', 'Low', 'Standard']
# High... 2463 entries
# Low... 1894 entries
# Standard... 3796 entries
# (0.7, 'fracweight') df_full = 9356  cv = 4550 , dv = 4806
# (0.9, 'medianscore') df_full = 6864  cv = 3349 , dv = 3515
# (0.95, 'medianscore') df_full = 6030  cv = 2941 , dv = 3089
# (0.95, 'avgscore') df_full = 5772  cv = 2812 , dv = 2960
# (0.9, 'avgscore') df_full = 6671  cv = 3251 , dv = 3420
# (0.7, 'medianscore') df_full = 8200  cv = 4000 , dv = 4200
# (0.8, 'medianscore') df_full = 7662  cv = 3742 , dv = 3920
# (0.8, 'fracweight') df_full = 8936  cv = 4357 , dv = 4579
# (0.7, 'avgscore') df_full = 8102  cv = 3954 , dv = 4148
# (0.85, 'avgscore') df_full = 7123  cv = 3479 , dv = 3644
# (0.75, 'avgscore') df_full = 7814  cv = 3813 , dv = 4001
# (0.85, 'medianscore') df_full = 7300  cv = 3562 , dv = 3738
# (0.8, 'avgscore') df_full = 7508  cv = 3667 , dv = 3841
# (0.75, 'fracweight') df_full = 9174  cv = 4464 , dv = 4710
# (0.75, 'medianscore') df_full = 7951  cv = 3882 , dv = 4069
# (0.85, 'fracweight') df_full = 8653  cv = 4232 , dv = 4421
# (0.9, 'fracweight') df_full = 8238  cv = 4029 , dv = 4209
# (0.95, 'fracweight') df_full = 7423  cv = 3630 , dv = 3793
# ##### SCE #####
# ['High', 'Low', 'Standard']
# High... 2429 entries
# Low... 1772 entries
# Standard... 3887 entries
# (0.7, 'fracweight') df_full = 9262  cv = 4550 , dv = 4712
# (0.9, 'medianscore') df_full = 6865  cv = 3349 , dv = 3516
# (0.95, 'medianscore') df_full = 5980  cv = 2941 , dv = 3039
# (0.95, 'avgscore') df_full = 5736  cv = 2812 , dv = 2924
# (0.9, 'avgscore') df_full = 6630  cv = 3251 , dv = 3379
# (0.7, 'medianscore') df_full = 8155  cv = 4000 , dv = 4155
# (0.8, 'medianscore') df_full = 7654  cv = 3742 , dv = 3912
# (0.8, 'fracweight') df_full = 8866  cv = 4357 , dv = 4509
# (0.7, 'avgscore') df_full = 8070  cv = 3954 , dv = 4116
# (0.85, 'avgscore') df_full = 7123  cv = 3479 , dv = 3644
# (0.75, 'avgscore') df_full = 7803  cv = 3813 , dv = 3990
# (0.85, 'medianscore') df_full = 7311  cv = 3562 , dv = 3749
# (0.8, 'avgscore') df_full = 7505  cv = 3667 , dv = 3838
# (0.75, 'fracweight') df_full = 9078  cv = 4464 , dv = 4614
# (0.75, 'medianscore') df_full = 7940  cv = 3882 , dv = 4058
# (0.85, 'fracweight') df_full = 8611  cv = 4232 , dv = 4379
# (0.9, 'fracweight') df_full = 8223  cv = 4029 , dv = 4194
# (0.95, 'fracweight') df_full = 7427  cv = 3630 , dv = 3797
# ##### CV #####
# ['High', 'Low', 'Standard']
# High... 2338 entries
# Low... 1810 entries
# Standard... 3690 entries
# (0.7, 'fracweight') df_full = 9100  cv = 4550 , dv = 4550
# (0.9, 'medianscore') df_full = 6698  cv = 3349 , dv = 3349
# (0.95, 'medianscore') df_full = 5882  cv = 2941 , dv = 2941
# (0.95, 'avgscore') df_full = 5624  cv = 2812 , dv = 2812
# (0.9, 'avgscore') df_full = 6502  cv = 3251 , dv = 3251
# (0.7, 'medianscore') df_full = 8000  cv = 4000 , dv = 4000
# (0.8, 'medianscore') df_full = 7484  cv = 3742 , dv = 3742
# (0.8, 'fracweight') df_full = 8714  cv = 4357 , dv = 4357
# (0.7, 'avgscore') df_full = 7908  cv = 3954 , dv = 3954
# (0.85, 'avgscore') df_full = 6958  cv = 3479 , dv = 3479
# (0.75, 'avgscore') df_full = 7626  cv = 3813 , dv = 3813
# (0.85, 'medianscore') df_full = 7124  cv = 3562 , dv = 3562
# (0.8, 'avgscore') df_full = 7334  cv = 3667 , dv = 3667
# (0.75, 'fracweight') df_full = 8928  cv = 4464 , dv = 4464
# (0.75, 'medianscore') df_full = 7764  cv = 3882 , dv = 3882
# (0.85, 'fracweight') df_full = 8464  cv = 4232 , dv = 4232
# (0.9, 'fracweight') df_full = 8058  cv = 4029 , dv = 4029
# (0.95, 'fracweight') df_full = 7260  cv = 3630 , dv = 3630
# ##### recomb2 #####
# ['High', 'Low', 'Standard']
# High... 1828 entries
# Low... 1716 entries
# Standard... 4834 entries
# (0.7, 'fracweight') df_full = 9298  cv = 4550 , dv = 4748
# (0.9, 'medianscore') df_full = 6781  cv = 3349 , dv = 3432
# (0.95, 'medianscore') df_full = 5900  cv = 2941 , dv = 2959
# (0.95, 'avgscore') df_full = 5609  cv = 2812 , dv = 2797
# (0.9, 'avgscore') df_full = 6587  cv = 3251 , dv = 3336
# (0.7, 'medianscore') df_full = 8112  cv = 4000 , dv = 4112
# (0.8, 'medianscore') df_full = 7612  cv = 3742 , dv = 3870
# (0.8, 'fracweight') df_full = 8889  cv = 4357 , dv = 4532
# (0.7, 'avgscore') df_full = 8020  cv = 3954 , dv = 4066
# (0.85, 'avgscore') df_full = 7078  cv = 3479 , dv = 3599
# (0.75, 'avgscore') df_full = 7748  cv = 3813 , dv = 3935
# (0.85, 'medianscore') df_full = 7265  cv = 3562 , dv = 3703
# (0.8, 'avgscore') df_full = 7471  cv = 3667 , dv = 3804
# (0.75, 'fracweight') df_full = 9116  cv = 4464 , dv = 4652
# (0.75, 'medianscore') df_full = 7881  cv = 3882 , dv = 3999
# (0.85, 'fracweight') df_full = 8610  cv = 4232 , dv = 4378
# (0.9, 'fracweight') df_full = 8159  cv = 4029 , dv = 4130
# (0.95, 'fracweight') df_full = 7384  cv = 3630 , dv = 3754
# Warning in <TClass::Init>: no dictionary for class larcv::EventImage2D is available
# Warning in <TClass::Init>: no dictionary for class larcv::EventBase is available
# Warning in <TClass::Init>: no dictionary for class larcv::Image2D is available
# Warning in <TClass::Init>: no dictionary for class larcv::ImageMeta is available
# Warning in <TClass::Init>: no dictionary for class larcv::Point2D is available
# Warning in <TClass::Init>: no dictionary for class larcv::EventChStatus is available
# Warning in <TClass::Init>: no dictionary for class larcv::EventSparseImage is available
# Warning in <TClass::Init>: no dictionary for class larcv::SparseImage is available
# Warning in <TClass::Init>: no dictionary for class larcv::EventClusterMask is available
# Warning in <TClass::Init>: no dictionary for class larcv::ChStatus is available
# Warning in <TClass::Init>: no dictionary for class larcv::EventROI is available
# Warning in <TClass::Init>: no dictionary for class larcv::ROI is available
# Warning in <TClass::Init>: no dictionary for class larcv::Vertex is available
# Warning in <TClass::Init>: no dictionary for class larcv::EventPGraph is available
# Warning in <TClass::Init>: no dictionary for class larcv::PGraph is available
# Warning in <TClass::Init>: no dictionary for class larcv::EventPixel2D is available
# Warning in <TClass::Init>: no dictionary for class larcv::Pixel2DCluster is available
# Warning in <TClass::Init>: no dictionary for class larcv::Pixel2D is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_hit is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_base is available
# Warning in <TClass::Init>: no dictionary for class larlite::output_base is available
# Warning in <TClass::Init>: no dictionary for class larlite::data_base is available
# Warning in <TClass::Init>: no dictionary for class larlite::hit is available
# Warning in <TClass::Init>: no dictionary for class larlite::geo::WireID is available
# Warning in <TClass::Init>: no dictionary for class larlite::product_id is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_spacepoint is available
# Warning in <TClass::Init>: no dictionary for class larlite::spacepoint is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_ass is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_gtruth is available
# Warning in <TClass::Init>: no dictionary for class larlite::gtruth is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_mctruth is available
# Warning in <TClass::Init>: no dictionary for class larlite::mctruth is available
# Warning in <TClass::Init>: no dictionary for class larlite::mcnu is available
# Warning in <TClass::Init>: no dictionary for class larlite::mcpart is available
# Warning in <TClass::Init>: no dictionary for class larlite::mctrajectory is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_mcflux is available
# Warning in <TClass::Init>: no dictionary for class larlite::mcflux is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_mcshower is available
# Warning in <TClass::Init>: no dictionary for class larlite::mcshower is available
# Warning in <TClass::Init>: no dictionary for class larlite::mcstep is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_daqheadertimeuboone is available
# Warning in <TClass::Init>: no dictionary for class larlite::daqheadertimeuboone is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_crthit is available
# Warning in <TClass::Init>: no dictionary for class larlite::crthit is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_crttrack is available
# Warning in <TClass::Init>: no dictionary for class larlite::crttrack is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_ophit is available
# Warning in <TClass::Init>: no dictionary for class larlite::ophit is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_opflash is available
# Warning in <TClass::Init>: no dictionary for class larlite::opflash is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_track is available
# Warning in <TClass::Init>: no dictionary for class larlite::track is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_vertex is available
# Warning in <TClass::Init>: no dictionary for class larlite::vertex is available
# Warning in <TClass::Init>: no dictionary for class larlite::trigger is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_mctrack is available
# Warning in <TClass::Init>: no dictionary for class larlite::mctrack is available
# Warning in <TClass::Init>: no dictionary for class pair<larlite::product_id,larlite::product_id> is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_mceventweight is available
# Warning in <TClass::Init>: no dictionary for class larlite::mceventweight is available
# Warning in <TClass::Init>: no dictionary for class larlite::swtrigger is available
# Warning in <TClass::Init>: no dictionary for class larlite::potsummary is available
# Warning in <TClass::Init>: no dictionary for class larlite::subrun_base is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_shower is available
# Warning in <TClass::Init>: no dictionary for class larlite::shower is available
# Warning in <TClass::Init>: no dictionary for class larlite::event_larflowcluster is available
# Warning in <TClass::Init>: no dictionary for class larlite::larflowcluster is available
# Warning in <TClass::Init>: no dictionary for class larlite::larflow3dhit is available
